# %%
print 'Hello!'
# Out:
# Hello!

# %%
print 3*3
# Out:
# 9

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem import MACCSkeys
import numpy as np
# Out:
# /usr/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
mol1 = Chem.MolFromSmiles('COc1cc2c(cc1OCCCN3CCOCC3)c(ncn2)Nc4ccc(c(c4)Cl)F')

# %%
mol2 = Chem.MolFromSmiles('COCCOc1cc2c(cc1OCCOC)ncnc2Nc3cccc(c3)C#C')

# %%
mol1

# %%
Draw.MolsToGridImage([mol1,mol2])
# Out:
# <PIL.Image.Image image mode=RGBA size=600x200 at 0x7F2D0CF48F10>

# %%
fp1 = MACCSkeys.GenMACCSKeys(mol1)
fp2 = MACCSkeys.GenMACCSKeys(mol2)

# %%
fp_a1 = np.array(map(int, fp1.ToBitString()))
fp_a2 = np.array(map(int, fp2.ToBitString()))

# %%
from scipy.spatial.distance import dice

# %%
dice(fp_a1, fp_a2)
# Out:
# 0.18181818181818182

# %%
from rdkit.Chem.Draw import SimilarityMaps

# %%
# %matplotlib inline

# %%
fig, maxweight = SimilarityMaps.GetSimilarityMapForFingerprint(mol1, mol2, SimilarityMaps.GetMorganFingerprint)

# %%
from rdkit.Chem import PandasTools

# %%
import pandas as pd

# %%
df = PandasTools.LoadSDF('/home/samo/Work/websdf/test.sdf')

# %%
df.head(1)
# Out:
#         ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 0  DB01322  <img src="data:image/png;base64,..." alt="Mol"/>  2.6648  232.278994301

# %%
from rdkit.Chem import Descriptors

# %%
df['HAC'] = df['ROMol'].map(Descriptors.HeavyAtomCount)

# %%
df.head(1)
# Out:
#         ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 0  DB01322  <img src="data:image/png;base64,..." alt="Mol"/>  2.6648  232.278994301   17

# %%
df['HAC'] > 15
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26     True
# 27     True
# 28     True
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35     True
# 36    False
# 37     True
# 38    False
# 39     True
# 40    False
# 41     True
# 42    False
# 43     True
# 44    False
# 45    False
# 46     True
# 47    False
# 48     True
# 49     True
# 50    False
# 51    False
# 52    False
# 53     True
# 54    False
# 55    False
# 56    False
# 57     True
# 58     True
# 59     True
# 60     True
# 61     True
# 62    False
# 63     True
# 64     True
# 65     True
# 66     True
# 67     True
# 68     True
# 69     True
# 70     True
# 71     True
# 72     True
# 73    False
# 74     True
# 75     True
# 76    False
# 77    False
# 78     True
# 79    False
# 80     True
# 81     True
# 82     True
# 83     True
# 84    False
# 85     True
# 86    False
# 87     True
# 88     True
# 89     True
# 90     True
# 91    False
# 92     True
# 93    False
# 94     True
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: HAC, dtype: bool

# %%
df[df['HAC'] >= 25]
# Out:
#          ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 35  DB01538                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>   2.2959  343.422991943   25
# 49  DB01569  <img src="data:image/png;base64,..." alt="Mol"/>   2.5852  344.450991653   25
# 61  DB01274                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>   2.2233  344.410992233   25
# 66  DB01295                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>  2.58422  345.438991943   25
